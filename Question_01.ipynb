# %%
# Date: 18th September 2023
# CSC461 - Assignment1 - Web Scraping
# Name: Muhammad Anas
# Registration No.: Fa21-BSE-126
# Question 1: List Movies Title and their rating in Excel File

# %%
import requests
from bs4 import BeautifulSoup
import openpyxl
import time
import pandas

# %%
# 1-The Shawshank
# 2-The Godfather
# 3-The Dark Knight
# 4-The Godfather: Part II
# 5-Fight Club

#List For Movies Urls

movie_urls = [
    "https://www.imdb.com/title/tt0111161/",
    "https://www.imdb.com/title/tt0068646/",
    "https://www.imdb.com/title/tt0468569/",
    "https://www.imdb.com/title/tt0071562/",
    "https://www.imdb.com/title/tt0137523/"
]

drivers = {
 'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.1000.0 Safari/537.36',
 'Accept-Language': 'en-US,en;q=0.9',
 'Accept-Encoding': 'gzip, deflate, br',
 'Connection': 'keep-alive',
 'Cache-Control': 'max-age=0',
 'Upgrade-Insecure-Requests': '1',
}

# %%
movies = []
for i in movie_urls :
  response = requests.get(i , headers=drivers)
  soup = BeautifulSoup(response.text , 'html5lib')
  Title = soup.find('span' ,attrs={'class' : 'sc-afe43def-1 fDTGTb'}).text
  Raiting = soup.find('span' ,attrs={'class' : 'sc-bde20123-1 iZlgcd'}).text
  movies.append({
  'Title' : Title,
  'Rating':Raiting
  })
  time.sleep(1)

# %%
movies
# Out:
# [{'Title': 'The Shawshank Redemption', 'Rating': '9.3'},
#  {'Title': 'The Godfather', 'Rating': '9.2'},
#  {'Title': 'The Dark Knight', 'Rating': '9.0'},
#  {'Title': 'The Godfather Part II', 'Rating': '9.0'},
#  {'Title': 'Fight Club', 'Rating': '8.8'}]

# %%
excel= pandas.DataFrame(movies)

# %%
excel_file_path= "Question 1.xlsx"
excel.to_excel(excel_file_path, index=False)

# %%
excel
# Out:
#                       Title Rating
# 0  The Shawshank Redemption    9.3
# 1             The Godfather    9.2
# 2           The Dark Knight    9.0
# 3     The Godfather Part II    9.0
# 4                Fight Club    8.8
